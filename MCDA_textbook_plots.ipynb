# %% [markdown]
# <a href="https://colab.research.google.com/github/marlEvalDissertation/marlEvalDiss/blob/main/MCDA_textbook_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Replication of plots in T. Stewart, “Value function methods for discrete choice,” 2023, unpublished.
# ## Roland Dubb
#
# ## January 2024
#
# This code replicated two plots of value functions found in an unpublished note pack by Emiritus Professor Theodor Stewart titled "Value function methods for discrete choice".
#
# Cited as:
# T. Stewart, “Value function methods for discrete choice,” 2023, unpublished.
#
# The plots appear in section 2.4 (Figures 11 and 12) of my master of science dissertation, supervised by Assoc. Prof. Jonathan Shock in his lab, Shocklab, in the Department of Applied Mathematics at the University of Cape Town. The dissertation is titled:
#
# **Addressing Deep Reinforcement Learning Empirical Algorithm Performance Evaluations**
#
# The code is produced using ChatGPT.

# %%
# Install ggplot2 package if not already installed
if (!requireNamespace("ggplot2", quietly = TRUE)) {
  install.packages("ggplot2")
}

# Load ggplot2 package
library(ggplot2)

# Create data frame for the points
data <- data.frame(
  x = c(0, 3, 7, 14, 28),
  y = c(0, 25, 50, 75, 100)
)

# Create piece-wise linear plot
plot <- ggplot(data, aes(x = x, y = y)) +
  geom_line() +
  geom_point(shape = 15, size = 5, color = "black") +  # Square points, larger size, black color
  labs(
    title = "Impact on attractiveness to US staff",
    x = "Flights per week",
    y = "Preferential value"
  ) +
  scale_x_continuous(
    breaks = c(0, 7, 14, 21, 28),
    labels = c("0", "7", "14", "21", "28")
  ) +
  ylim(0, 100) +
  theme(
    panel.grid.major = element_line(color = "black", linetype = "solid"),
    panel.grid.minor = element_line(color = "gray", linetype = "dashed"),
    axis.text = element_text(size = 16,face="bold"),
    axis.title = element_text(size = 16,face="bold"),
    plot.title = element_text(size = 20,face="bold")
  )

# Print the plot
print(plot)
# Out:
# plot without title

# %%
# Load ggplot2 package
library(ggplot2)

# Create data frame for the points
data <- data.frame(
  x = c(4, 8, 10, 20, 50),
  y = c(0, 25, 50, 75, 100)
)

# Create piece-wise linear plot
plot <- ggplot(data, aes(x = x, y = y)) +
  geom_line() +
  geom_point(shape = 15, size = 5, color = "black") +  # Square points, larger size, black color
  labs(
    x = "Number of applicants",  # Updated x-axis title
    y = "Preferential value"     # Updated y-axis title
  ) +
  scale_x_continuous(
    limits = c(0, 50),            # Updated x-axis limits
    breaks = c(0, 10, 20, 30, 40, 50),  # Adjusted breaks
    labels = c("0", "10", "20", "30", "40", "50") # Adjusted labels
  ) +
  scale_y_continuous(limits = c(0, 100)) + # Updated y-axis limits
  theme(
    panel.grid.major = element_line(color = "black", linetype = "solid"),
    panel.grid.minor = element_line(color = "gray", linetype = "dashed"),
    axis.text = element_text(size = 16, face = "bold"),
    axis.title = element_text(size = 16, face = "bold")
  )

# Print the plot
print(plot)
# Out:
# plot without title
